# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
n = int(input("Entry numbers?: "))
d = {}
for i in range(0,n):
  j = input("Insert entry: ")
  x = j.split(" ")
  loc, post,road,house,size,rent = x
  id = post[-2:]+road+house
  if loc not in d.keys():
    d[loc] = {id:[size,int(rent)]}
  else:
    d[loc][id] = [size,int(rent)]
print(d)
# Out:
# Entry numbers?: 5
# Insert entry: Mirpur 1216 5A 103 1800sqft 33000
# Insert entry: Dhanmondi 1209 9A 128 1700sqft 45000
# Insert entry: Dhanmondi 1209 4A 43 1616sqft 40000
# Insert entry: Mirpur 1216 6B 10 1350sqft 23000
# Insert entry: Gulshan 1212 7C 102 2000sqft 60000
# {'Mirpur': {'165A103': ['1800sqft', '33000'], '166B10': ['1350sqft', '23000']}, 'Dhanmondi': {'099A128': ['1700sqft', '45000'], '094A43': ['1616sqft', '40000']}, 'Gulshan': {'127C102': ['2000sqft', '60000']}}

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
class Dominos:

  def __init__(self,*items):
    i = 1
    if i ==1:
      print("Domino’s. The Pizza Delivery Experts.")
    i+=1
    self.n1 = n1

  def add

class Pizza:

  def __init__(self,na1,na2,na3 = "Onion",na4):
    self.na1 = na1
    self.na2 = na2
    self.na3 = na3
    self.na4 = na4




dom = Dominos("Domino's Pizza")
print("1.=================================")
p1 = Pizza("Spicy Chicken","Spicy Chicken","Onion","Capsicum")
dom.addPizza(p1)
p2 = Pizza("Margherita","Mozzarella Cheese")
print("2.=================================")
p3 = Pizza("Beef Kala Bhuna")
print("3.=================================")
p3.setToppings("Curried Beef","Capsicum","Paprika","Onion")
print("4.=================================")
dom.addPizza(p2,p3)
p4 = Pizza("Chicken Dominator","Barbecue Chicken,Spicy Chicken,Grilled Chicken")
p5 = Pizza("Beefzza","Minced Beef","Beef Pepperoni","Onion","Jalapeno")
dom.addPizza(p4,p5)
print("5.=================================")
dom.showMenu()
print("6.=================================")

# %%
Domino’s. The Pizza Delivery Experts.
1.======================================
2.======================================
A pizza without toppings cannot be created.
3.======================================
Toppings added to Beef Kala Bhuna pizza.
4.======================================
5.======================================
Total number of pizzas: 5
Chicken Pizza:2
Name:Spicy Chicken, Toppings: ['Spicy Chicken', 'Onion', 'Capsicum']
Name:Chicken Dominator, Toppings: ['Barbecue Chicken,Spicy Chicken,Grilled Chicken']

Beef Pizza:2
Name:Beef Kala Bhuna, Toppings: ['Curried Beef', 'Capsicum', 'Paprika', 'Onion']
Name:Beefzza, Toppings: ['Minced Beef', 'Beef Pepperoni', 'Onion', 'Jalapeno']

Cheese Pizza: 1
Name:Margherita, Toppings: ['Mozzarella Cheese']
6.======================================

# %%
class Dominos:
    total = 0
    chicken = 0
    beef = 0
    cheese = 0
    menu = {}

    def __init__(self, name):
        self.name = name
        print("Domino’s. The Pizza Delivery Experts.")

    def addPizza(self, *pizzas):
        for pizza in pizzas:
            if 'chicken' in pizza.name.lower():
                Dominos.chicken += 1
                Dominos.total += 1

                if "Chicken Pizza" not in Dominos.menu.keys():
                    Dominos.menu["Chicken Pizza"] = {pizza.name: pizza.toppings}
                else:
                    Dominos.menu["Chicken Pizza"][pizza.name] = pizza.toppings
            elif 'beef' in pizza.name.lower():
                Dominos.beef += 1
                Dominos.total += 1

                if "Beef Pizza" not in Dominos.menu.keys():
                    Dominos.menu["Beef Pizza"] = {pizza.name: pizza.toppings}
                else:
                    Dominos.menu["Beef Pizza"][pizza.name] = pizza.toppings
            else:
                Dominos.cheese += 1
                Dominos.total += 1

                if "Cheese Pizza" not in Dominos.menu.keys():
                    Dominos.menu["Cheese Pizza"] = {pizza.name: pizza.toppings}
                else:
                    Dominos.menu["Cheese Pizza"][pizza.name] = pizza.toppings

    def showMenu(self):
        print(f"Total number of pizzas: {Dominos.total}")

        print(f"Chicken Pizza:{Dominos.chicken}")
        for name, toppings in Dominos.menu["Chicken Pizza"].items():
            print(f"Name:{name}, Toppings: {toppings}")
        print()

        print(f"Beef Pizza:{Dominos.beef}")
        for name, toppings in Dominos.menu["Beef Pizza"].items():
            print(f"Name:{name}, Toppings: {toppings}")
        print()

        print(f"Cheese Pizza: {Dominos.cheese}")
        for name, toppings in Dominos.menu["Cheese Pizza"].items():
            print(f"Name:{name}, Toppings: {toppings}")

class Pizza:
    def __init__(self, name, *info):
        self.name = name
        self.toppings = list(info)
        if len(self.toppings) == 0:
            print("A pizza without toppings cannot be created.")

    def setToppings(self, *info):
        self.toppings = list(info)
        print(f"Toppings added to {self.name} pizza.")


dom = Dominos("Domino's Pizza")
print("1.=================================")
p1 = Pizza("Spicy Chicken","Spicy Chicken","Onion","Capsicum")
dom.addPizza(p1)
p2 = Pizza("Margherita","Mozzarella Cheese")
print("2.=================================")
p3 = Pizza("Beef Kala Bhuna")
print("3.=================================")
p3.setToppings("Curried Beef","Capsicum","Paprika","Onion")
print("4.=================================")
dom.addPizza(p2,p3)
p4 = Pizza("Chicken Dominator","Barbecue Chicken,Spicy Chicken,Grilled Chicken")
p5 = Pizza("Beefzza","Minced Beef","Beef Pepperoni","Onion","Jalapeno")
dom.addPizza(p4,p5)
print("5.=================================")
dom.showMenu()
print("6.=================================")
# Out:
# Domino’s. The Pizza Delivery Experts.
# 1.=================================
# 2.=================================
# A pizza without toppings cannot be created.
# 3.=================================
# Toppings added to Beef Kala Bhuna pizza.
# 4.=================================
# 5.=================================
# Total number of pizzas: 5
# Chicken Pizza:2
# Name:Spicy Chicken, Toppings: ['Spicy Chicken', 'Onion', 'Capsicum']
# Name:Chicken Dominator, Toppings: ['Barbecue Chicken,Spicy Chicken,Grilled Chicken']
#
# Beef Pizza:2
# Name:Beef Kala Bhuna, Toppings: ['Curried Beef', 'Capsicum', 'Paprika', 'Onion']
# Name:Beefzza, Toppings: ['Minced Beef', 'Beef Pepperoni', 'Onion', 'Jalapeno']
#
# Cheese Pizza: 1
# Name:Margherita, Toppings: ['Mozzarella Cheese']
# 6.=================================

# %%
class Dominos:
    def __init__(self, name):
        self.name = name
        self.total = 0
        self.chicken = 0
        self.beef = 0
        self.cheese = 0
        self.menu = {}
        print("Domino’s. The Pizza Delivery Experts.")

    def addPizza(self, *pizzas):
        for pizza in pizzas:
            if 'chicken' in pizza.name.lower():
                self.chicken += 1
                self.total += 1

                if "Chicken Pizza" not in self.menu.keys():
                    self.menu["Chicken Pizza"] = {pizza.name: pizza.toppings}
                else:
                    self.menu["Chicken Pizza"][pizza.name] = pizza.toppings
            elif 'beef' in pizza.name.lower():
                self.beef += 1
                self.total += 1

                if "Beef Pizza" not in self.menu.keys():
                    self.menu["Beef Pizza"] = {pizza.name: pizza.toppings}
                else:
                    self.menu["Beef Pizza"][pizza.name] = pizza.toppings
            else:
                self.cheese += 1
                self.total += 1

                if "Cheese Pizza" not in self.menu.keys():
                    self.menu["Cheese Pizza"] = {pizza.name: pizza.toppings}
                else:
                    self.menu["Cheese Pizza"][pizza.name] = pizza.toppings

    def showMenu(self):
        print(f"Total number of pizzas: {self.total}")

        print(f"Chicken Pizza:{self.chicken}")
        for name, toppings in self.menu["Chicken Pizza"].items():
            print(f"Name:{name}, Toppings: {toppings}")
        print()

        print(f"Beef Pizza:{self.beef}")
        for name, toppings in self.menu["Beef Pizza"].items():
            print(f"Name:{name}, Toppings: {toppings}")
        print()

        print(f"Cheese Pizza: {self.cheese}")
        for name, toppings in self.menu["Cheese Pizza"].items():
            print(f"Name:{name}, Toppings: {toppings}")

class Pizza:
    def __init__(self, name, *info):
        self.name = name
        self.toppings = list(info)
        if len(self.toppings) == 0:
            print("A pizza without toppings cannot be created.")

    def setToppings(self, *info):
        self.toppings = list(info)
        print(f"Toppings added to {self.name} pizza.")


dom = Dominos("Domino's Pizza")
print("1.=================================")
p1 = Pizza("Spicy Chicken","Spicy Chicken","Onion","Capsicum")
dom.addPizza(p1)
p2 = Pizza("Margherita","Mozzarella Cheese")
print("2.=================================")
p3 = Pizza("Beef Kala Bhuna")
print("3.=================================")
p3.setToppings("Curried Beef","Capsicum","Paprika","Onion")
print("4.=================================")
dom.addPizza(p2,p3)
p4 = Pizza("Chicken Dominator","Barbecue Chicken,Spicy Chicken,Grilled Chicken")
p5 = Pizza("Beefzza","Minced Beef","Beef Pepperoni","Onion","Jalapeno")
dom.addPizza(p4,p5)
print("5.=================================")
dom.showMenu()
print("6.=================================")
# Out:
# Domino’s. The Pizza Delivery Experts.
# 1.=================================
# 2.=================================
# A pizza without toppings cannot be created.
# 3.=================================
# Toppings added to Beef Kala Bhuna pizza.
# 4.=================================
# 5.=================================
# Total number of pizzas: 5
# Chicken Pizza:2
# Name:Spicy Chicken, Toppings: ['Spicy Chicken', 'Onion', 'Capsicum']
# Name:Chicken Dominator, Toppings: ['Barbecue Chicken,Spicy Chicken,Grilled Chicken']
#
# Beef Pizza:2
# Name:Beef Kala Bhuna, Toppings: ['Curried Beef', 'Capsicum', 'Paprika', 'Onion']
# Name:Beefzza, Toppings: ['Minced Beef', 'Beef Pepperoni', 'Onion', 'Jalapeno']
#
# Cheese Pizza: 1
# Name:Margherita, Toppings: ['Mozzarella Cheese']
# 6.=================================
