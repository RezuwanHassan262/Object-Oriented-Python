# %%
print('o')
# Out:
# o

# %% [markdown]
# 𝗤𝘂𝗲𝘀𝘁𝗶𝗼𝗻:
# Implement the design of the Motorcycle class so that the following output
# is produced:
# [Your code should work for any number of services added in the add_Services
# method]

# %%
class Motorcycle:
  count = 0

  def __init__ (self,name,year):
    self.name = name
    self.year = year
    Motorcycle.count +=1
  
  def add_Services(self,*parts):
    allParts = ""
    for i in parts:
      allParts =allParts+i+", "
    allParts = allParts[0:(len(allParts)-2)] 
    self.allParts = allParts
  
  def printMotorcycleDetail(self):
    print("Name: {} \nYear of manufacture: {} \nServices: {}".format(self.name,self.year,self.allParts))



# Do not change the following lines of code.
print('No. of Motorcycle =', Motorcycle.count)
m1 = Motorcycle('Yamaha MT-15', 2019)
m1.add_Services('Oil change', 'Replace coolant')
m2 = Motorcycle('Suzuki V-Strom 650', 2020)
m2.add_Services('Rear suspension check', 'New air filter', 'Oil change')
m3 = Motorcycle('Honda Gold Wing', 2017)
m3.add_Services('Adjustment of throttle and clutch', 'New oil filter')
print("=========================")
m1.printMotorcycleDetail()
print("=========================")
m2.printMotorcycleDetail()
print("=========================")
m3.printMotorcycleDetail()
print("=========================")
print('No. of Motorcycle =', Motorcycle.count)
# Out:
# No. of Motorcycle = 0
# ...
# Name: Yamaha MT-15
# Year of manufacture: 2019
# Services: Oil change, Replace coolant
# ...
# Name: Suzuki V-Strom 650
# Year of manufacture: 2020
# Services: Rear suspension check, New air filter, Oil change
# ...
# Name: Honda Gold Wing
# Year of manufacture: 2017
# Services: Adjustment of throttle and clutch, New oil filter
# ...
# No. of Motorcycle = 3

# %%
Output:
No. of Motorcycle = 0
=========================
Name: Yamaha MT-15
Year of manufacture: 2019
Services: Oil change, Replace coolant
=========================
Name: Suzuki V-Strom 650
Year of manufacture: 2020
Services: Rear suspension check, New air filter, Oil change
=========================
Name: Honda Gold Wing
Year of manufacture: 2017
Services: Adjustment of throttle and clutch, New oil filter
=========================
No. of Motorcycle = 3

# %%
class Anime:
   def __init__(self, name, rating, genre):
     self.name = name
     self.rating = rating
     self.genre = genre

   def add_character(self, *info):
     pass

   def __str__(self):
     s = f"Name: {self.name}\nRating: {self.rating}\nGenre: {self.genre}"
     return s

class Naruto(Anime):
  def __init__(self,name,rating,genre,rYear):
    super().__init__(name,rating,genre)
    self.rYear = rYear

  def release_year(self):
    return "{} has been released in {}!!!".format(self.name,self.rYear)


  def add_character(self,*info):
    main = []
    anti = []
    supporting = []
    l = len(info)
    i = 0
    while i<(l-1):
      if info[i+1] == "Main":
        main.append(info[i])
      elif info[i+1] == "Anti Hero":
        anti.append(info[i])
      elif info[i+1] == "Supporting":
        supporting.append(info[i])
      i+=1
    self.main = main
    self.anti = anti
    self.supporting = supporting
    #print("mm",main)
    #print("aa",anti)
    #print("ss",supporting)


  def __str__(self):
    return "Anime Details: \n{} \nRelease Year: {} \nCharacters: \nMain: {} \nAnti Hero: {} \nSupporting: {} ".format(Anime.__str__(self),self.rYear,self.main,self.anti,self.supporting)


class MyHeroAcademia(Anime):
  def __init__(self,name,rating,genre,season):
    super().__init__(name,rating,genre)
    self.season = season

  def season_status(self):
    return "{} has premiered {} seasons!!!!!!".format(self.name,self.season)


  def add_character(self,*info):
    main = []
    anti = []
    supporting = []
    l = len(info)
    i = 0
    while i<(l-1):
      if info[i+1] == "Main":
        main.append(info[i])
      elif info[i+1] == "Anti Hero":
        anti.append(info[i])
      elif info[i+1] == "Supporting":
        supporting.append(info[i])
      i+=1
    self.main = main
    self.anti = anti
    self.supporting = supporting
    #print("mm",main)
    #print("aa",anti)
    #print("ss",supporting)


  def __str__(self):
    return "Anime Details: \n{} \nSeason Premiered: {} \nCharacters: \nMain: {} \nAnti Hero: {} \nSupporting: {} ".format(Anime.__str__(self),self.season,self.main,self.anti,self.supporting)



# Write your codes here.
naruto = Naruto("Naruto", 10, "Adventure Fiction", 2007)
naruto.add_character("Naruto Uzumaki", "Main", "Itachi Uchiha", "Main", "Madara Uchiha", "Anti Hero", "Pain", "Supporting", "Shikamaru Nara", "Supporting")
print('1.------------------------------------')
print(naruto.release_year())
print('2.------------------------------------')
print(naruto)
print('3.====================================')

my_hero_academia = MyHeroAcademia("My Hero Academia", 8, "Superhero Fiction", 5)
my_hero_academia.add_character("Supporting", "Uraraka", "Anti Hero", "Nomu", "Supporting", "Mirio", "Main", "Midoriya", "Main", "Todoroki")
print('4.------------------------------------')
print(my_hero_academia.season_status())
print('5.------------------------------------')
print(my_hero_academia)
# Out:
# 1.------------------------------------
# Naruto has been released in 2007!!!
# 2.------------------------------------
# Anime Details:
# Name: Naruto
# Rating: 10
# Genre: Adventure Fiction
# Release Year: 2007
# Characters:
# Main: ['Naruto Uzumaki', 'Itachi Uchiha']
# Anti Hero: ['Madara Uchiha']
# Supporting: ['Pain', 'Shikamaru Nara']
# 3.====================================
# 4.------------------------------------
# My Hero Academia has premiered 5 seasons!!!!!!
# 5.------------------------------------
# Anime Details:
# Name: My Hero Academia
# Rating: 8
# Genre: Superhero Fiction
# Season Premiered: 5
# Characters:
# Main: ['Mirio', 'Midoriya']
# Anti Hero: ['Uraraka']
# Supporting: ['Nomu']

# %%
1.------------------------------------
Naruto has been released in 2007!!!
2.------------------------------------
Anime Details:
Name: Naruto
Rating: 10
Genre: Adventure Fiction
Release Year: 2007
Characters:
Main: ['Naruto Uzumaki', 'Itachi Uchiha']
Anti Hero: ['Madara Uchiha']
Supporting: ['Pain', 'Shikamaru Nara']
3.====================================
4.------------------------------------
My Hero Academia has premiered 5 seasons!!!
5.------------------------------------
Anime Details:
Name: My Hero Academia
Rating: 8
Genre: Superhero Fiction
Season Premiered: 5
Characters:
Supporting: ['Uraraka', 'Mirio']
Anti Hero: ['Nomu']
Main: ['Midoriya', 'Todoroki']
