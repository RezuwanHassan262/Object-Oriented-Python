# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Traveller:
  count = 0

  def __init__(self,name):
    self.name  = name
    Traveller.count += 1

  def buyTickets(self,*info):
    places = " "
    totalCost = 0
    z = len(info)
    i = 0
    while i <z:
      if i%2 == 0:
        places = places+info[i]+','
      else:
        totalCost += info[i]
      i+=1
    self.places = places[0:(len(places)-1)]
    self.totalCost = totalCost

  def printDetail(self):
    print("Name: {} \nTickets: {} \nCost: {}".format(self.name,self.places,self.totalCost))


# Do not change the following lines of code.
print("Total Traveller:", Traveller.count)
t1 = Traveller("Naruto")
t1.buyTickets("Mist Village",5000,"Rain Village", 10000)
t2 = Traveller("Minato")
t2.buyTickets("Cloud Village",15000,"Sand Village",1200,"Stone Village", 5000)
t3 = Traveller("Kushina")
t3.buyTickets("Leaves Village", 3000)
print("=========================")
t1.printDetail()
print("=========================")
t2.printDetail()
print("=========================")
t3.printDetail()
print("=========================")
print("Total Traveller:", Traveller.count)
# Out:
# Total Traveller: 0
# =========================
# Name: Naruto
# Tickets:  Mist Village,Rain Village
# Cost: 15000
# =========================
# Name: Minato
# Tickets:  Cloud Village,Sand Village,Stone Village
# Cost: 21200
# =========================
# Name: Kushina
# Tickets:  Leaves Village
# Cost: 3000
# =========================
# Total Traveller: 3

# %% [markdown]
# ##**Expected output**

# %%
Output:
Total Traveller: 0
=========================
Name: Naruto
Tickets: Mist Village, Rain Village
Cost: 15000
=========================
Name: Minato
Tickets: Cloud Village, Sand Village, Stone Village
Cost: 21200
=========================
Name: Kushina
Tickets: Leaves Village
Cost: 3000
=========================
Total Traveller: 3

# %% [markdown]
# Using try-except

# %%
class Traveller:
  count = 0

  def __init__(self,name):
    self.name  = name
    Traveller.count += 1

  def buyTickets(self,*info):
    places = " "
    totalCost = 0
    z = len(info)
    i = 0

    while i <z:
      try:
        x = int(info[i])
        totalCost += x
      except:
        places = places+info[i]+','
      i+=1
    self.places = places[0:(len(places)-1)]
    self.totalCost = totalCost

  def printDetail(self):
    print("Name: {} \nTickets: {} \nCost: {}".format(self.name,self.places,self.totalCost))


# Do not change the following lines of code.
print("Total Traveller:", Traveller.count)
t1 = Traveller("Naruto")
t1.buyTickets("Mist Village",5000,"Rain Village", 10000)
t2 = Traveller("Minato")
t2.buyTickets("Cloud Village",15000,"Sand Village",1200,"Stone Village", 5000)
t3 = Traveller("Kushina")
t3.buyTickets("Leaves Village", 3000)
print("=========================")
t1.printDetail()
print("=========================")
t2.printDetail()
print("=========================")
t3.printDetail()
print("=========================")
print("Total Traveller:", Traveller.count)
# Out:
# Total Traveller: 0
# =========================
# Name: Naruto
# Tickets:  Mist Village,Rain Village
# Cost: 15000
# =========================
# Name: Minato
# Tickets:  Cloud Village,Sand Village,Stone Village
# Cost: 21200
# =========================
# Name: Kushina
# Tickets:  Leaves Village
# Cost: 3000
# =========================
# Total Traveller: 3

# %%
Output:
Total Traveller: 0
=========================
Name: Naruto
Tickets: Mist Village, Rain Village
Cost: 15000
=========================
Name: Minato
Tickets: Cloud Village, Sand Village, Stone Village
Cost: 21200
=========================
Name: Kushina
Tickets: Leaves Village
Cost: 3000
=========================
Total Traveller: 3
