# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class PlayerEarning:

  def __init__(self,name):
    self.name = name

  def calculateTotal(self,earning, goals = 0):
    self.earning = earning
    if goals == 0:
      bonus = 0
    elif goals > 30:
      bonus = ((5/100) *earning) +10000
    else:
      bonus = (5/100) * earning
    self.bonus = bonus
    self.total = earning+bonus

  def printDetails(self):
    print("Player Name: {} \nPlayer Season Earning without bonus: {} \nBonus: {} \nPlayer Season Earning After Bonus: {}".format(self.name,self.earning,self.bonus,self.total))


print("**********************")
player1 = PlayerEarning('Buffon')
player1.calculateTotal(250000)
player1.printDetails()
print("\n**********************")
player2 = PlayerEarning('Dybala')
player2.calculateTotal(250000, 31)
player2.printDetails()
print("\n**********************")
player3 = PlayerEarning('Cuadrado')
player3.calculateTotal(250000, 20)
player3.printDetails()
# Out:
# **********************
# Player Name: Buffon
# Player Season Earning without bonus: 250000
# Bonus: 0
# Player Season Earning After Bonus: 250000
#
# **********************
# Player Name: Dybala
# Player Season Earning without bonus: 250000
# Bonus: 22500.0
# Player Season Earning After Bonus: 272500.0
#
# **********************
# Player Name: Cuadrado
# Player Season Earning without bonus: 250000
# Bonus: 12500.0
# Player Season Earning After Bonus: 262500.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class myList:

  def __init__(self,*nums):
    self.nums = nums
    self.l = list(nums)


  def sum(self):
    print("Sum:",sum(self.l))

  def average(self):
    le = len(self.l)
    if le == 0:
      avg = (sum(self.l))/5  
    else:
      avg = (sum(self.l))/le
    print("Average:",avg)

  
  def merge(self,*nums2):
    newL = self.nums + nums2
    self.l = list(newL)

l1 = myList(2,3,4,5,6) #you might need a list inside your class to store the values
l1.sum()
l1.merge(4,5,9)
l1.sum()
l1.average()
print("-----------------------------")
l2 = myList()
l2.average()
l2.merge(1,2,4,8)
l2.sum()
# Out:
# Sum: 20
# Sum: 38
# Average: 4.75
# -----------------------------
# Average: 0.0
# Sum: 15

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Bird:
  def __init__(self,name, canFly = False):
    self.name = name
    self.canFly = canFly
    self.types ="Flightless Birds"
  
  def fly(self):
    if self.canFly == True:
      print(self.name,"can fly")
    else:
      print(self.name,"can not fly")

  def setType(self,types):
    self.types = types
  
  def printDetail(self):
    print("Name:", self.name)
    print("Type:",self.types)

ostrich = Bird('Ostrich')
duck = Bird("Duck", True)
owl = Bird('Owl', True)
print("###########################")
ostrich.fly()
duck.fly()
owl.fly()
duck.setType('Water Birds')
owl.setType('Birds of Prey')
print("=========================")
ostrich.printDetail()
print("=========================")
duck.printDetail()
print("=========================")
owl.printDetail()
# Out:
# ###########################
# Ostrich can not fly
# Duck can fly
# Owl can fly
# ...
# Name: Ostrich
# Type: Flightless Birds
# ...
# Name: Duck
# Type: Water Birds
# ...
# Name: Owl
# Type: Birds of Prey

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
class Account:
  count = 0

  def __init__(self,name,age,occ,salary):
    self.name = name
    self.age = age
    self.occ = occ
    self.salary = salary
    self.bonus = 0
    Account.count += 1

  def addMoney(self,bonus=0):
    self.bonus = bonus

  def withdrawMoney(self,withdraw = 0):
    if withdraw > self.salary:
      self.salary = self.salary
    else:
      self.salary  =self.salary-withdraw


  def printDetails(self):
    total = self.bonus+self.salary
    print("Name: {}".format(self.name))
    print("Age: {}".format(self.age))
    print("Occupation: {}".format(self.occ))
    print("Total Amount: {}".format(total))


print('No of account holders:', Account.count)
print("=========================")
p1 = Account("Abdul", 45, "Service Holder", 500000)
p1.addMoney(300000)
p1.printDetails()
print("=========================")
p2 = Account("Rahim", 55, "Businessman", 700000)
p2.withdrawMoney(700000)
p2.printDetails()
print("=========================")
p3 = Account("Ashraf", 62, "Govt. Officer", 200000)
p3.withdrawMoney(250000)
p3.printDetails()
print("=========================")
print('No of account holders:', Account.count)
# Out:
# No of account holders: 0
# ...
# Name: Abdul
# Age: 45
# Occupation: Service Holder
# Total Amount: 800000
# ...
# Name: Rahim
# Age: 55
# Occupation: Businessman
# Total Amount: 0
# ...
# Name: Ashraf
# Age: 62
# Occupation: Govt. Officer
# Total Amount: 200000
# ...
# No of account holders: 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Smartphone:

  def __init__(self,model = None):
    self.newName = model
    self.dis = []
    self.ram = []

  def setName(self,model):
    self.newName = model
  
  def addFeature(self,*features):    
    if self.newName == None:
      print("Feature can not be added without phone name")
    else:
      if features[0]=="Display" and features[1] not in self.dis:
        self.dis.append(features[1])
      elif features[0]=="Ram" and features[1] not in self.ram:
        self.ram.append(features[1])


  def printDetail(self):
    #print('fffffffff',self.dis,self.ram)
    d = ""
    r = ""
    for i in self.dis:
      d =d+ str(i)+", "
    for i in self.ram:
      r = r+str(i)+", "
    d = d[0:(len(d)-2)]
    r = r[0:(len(r)-2)]


    if len(self.ram) != 0:
      print("Phone Name:",self.newName)
      print("Display:",d)
      print("Ram:",r)
    elif len(self.ram) == 0:
      print("Phone Name:",self.newName)
      print("Display:",d)


s1 = Smartphone()
print("=================================")
s1.addFeature("Display", "6.1 inch")
print("=================================")
s1.setName("Samsung Note 20")
s1.addFeature("Display", "6.1 inch")
s1.printDetail()
print("=================================")
s2 = Smartphone("Iphone 12 Pro")
s2.addFeature("Display", "6.2 inch")
s2.addFeature("Ram", "6 GB")
print("=================================")
s2.printDetail()
s2.addFeature("Display", "Amoled panel")
s2.addFeature("Ram", "DDR5")
print("=================================")
s2.printDetail()
print("=================================")
# Out:
# ...
# Feature can not be added without phone name
# ...
# Phone Name: Samsung Note 20
# Display: 6.1 inch
# ...
# Phone Name: Iphone 12 Pro
# Display: 6.2 inch
# Ram: 6 GB
# ...
# Phone Name: Iphone 12 Pro
# Display: 6.2 inch, Amoled panel
# Ram: 6 GB, DDR5
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
class Student:
  cse = 0
  bba = 0
  total = 0
  def __init__(self,name,dept):
    self.name = name
    self.dept = dept
    Student.total += 1
    print("Creating Student Number:",Student.total)
    if dept == "CSE":
      Student.cse += 1
    else:
      Student.bba += 1
  
  def individualInfo(self):
    print("{} is from {} department".format(self.name,self.dept))
    if self.dept == "CSE":
      print("Serial of {} among all stuents is: {}".format(self.name,Student.total))
      print("Serial of {} in CSE department is: {}".format(self.name,Student.cse))
    elif self.dept == "BBA":
      print("Serial of {} among all stuents is: {}".format(self.name,Student.total))
      print("Serial of {} in CSE department is: {}".format(self.name,Student.bba))

  def totalInfo(self):
    print("Total Number of Student: {} \nTotal Number of CSE Student: {} \nTotal Number of BBA Student: {}".format(Student.total,Student.cse,Student.bba))



s1 = Student("Naruto", "CSE")
print('----------------------')
s1.individualInfo()
print('#############################')
s1.totalInfo()
print('============================')
s2 = Student("Sakura", "BBA")
print('----------------------')
s2.individualInfo()
print('#############################')
s2.totalInfo()
print('============================')
s3 = Student("Shikamaru", "CSE")
print('----------------------')
s3.individualInfo()
print('#############################')
s3.totalInfo()
print('============================')
s4 = Student("Deidara", "BBA")
print('----------------------')
s4.individualInfo()
print('#############################')
s4.totalInfo()
# Out:
# Creating Student Number: 1
# ----------------------
# Naruto is from CSE department
# Serial of Naruto among all stuents is: 1
# Serial of Naruto in CSE department is: 1
# #############################
# Total Number of Student: 1
# Total Number of CSE Student: 1
# Total Number of BBA Student: 0
# ...
# Creating Student Number: 2
# ----------------------
# Sakura is from BBA department
# Serial of Sakura among all stuents is: 2
# Serial of Sakura in CSE department is: 1
# #############################
# Total Number of Student: 2
# Total Number of CSE Student: 1
# Total Number of BBA Student: 1
# ...
# Creating Student Number: 3
# ----------------------
# Shikamaru is from CSE department
# Serial of Shikamaru among all stuents is: 3
# Serial of Shikamaru in CSE department is: 2
# #############################
# Total Number of Student: 3
# Total Number of CSE Student: 2
# Total Number of BBA Student: 1
# ...
# Creating Student Number: 4
# ----------------------
# Deidara is from BBA department
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class book:
  def __init__(self, name):
    self.name = name
    self.genre='biography'
  def review(self):
    print('This book is just out of the world,mind-blowing!')

class fiction(book):
  def __init__(self,name,genre):
    super().__init__(name)
    self.genre = genre

  def review(self):
    print("{} which is a {} is just out of the world, mind-blowing!".format(self.name,self.genre))

class nonfiction(book):
  def __init__(self,name):
    super().__init__(name)

  def review(self):
    print("{} which is a {} is just out of the world, mind-blowing!".format(self.name,self.genre))


b1 = fiction('The Shining','Psychological horror')
b2 = nonfiction('A Beautiful Mind')
b1.review()
print('=========================')
b2.review()
print('=========================')
# Out:
# The Shining which is a Psychological horror is just out of the world, mind-blowing!
# ...
# A Beautiful Mind which is a biography is just out of the world, mind-blowing!
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Processor:
  def __init__(self, model, thread, core):
    self.model = model
    self.core = core
    self.thread = thread
  def getInfo(self):
    return "Model:"+self.model+ "\nCores:"+str(self.core)+ "\nThreads:"+ str(self.thread)

class Intel(Processor):
  def __init__(self,model,core,thread,price):
    super().__init__(model,thread,core)
    self.price = price

  def getInfo(self):
    print("{} \nPrice: {} taka".format(Processor.getInfo(self),self.price))

class AMD(Processor):
  def __init__(self,model,core,thread,price):
    super().__init__(model,thread,core)
    self.price = price

  def getInfo(self):
    print("{} \nPrice: {} taka".format(Processor.getInfo(self),self.price))
  

# Write your code here
p1 = Intel("Intel i5 10th Gen",6,12,17000)
p2 = AMD("Ryzen 5 3500X",6,6,13800)
p3 = AMD("Ryzen 5 3600",6,12,16900)
print('======================')
p1.getInfo()
print('======================')
p2.getInfo()
print('======================')
p3.getInfo()
# Out:
# ...
# Model:Intel i5 10th Gen
# Cores:6
# Threads:12
# Price: 17000 taka
# ...
# Model:Ryzen 5 3500X
# Cores:6
# Threads:6
# Price: 13800 taka
# ...
# Model:Ryzen 5 3600
# Cores:6
# Threads:12
# Price: 16900 taka

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
class Fruit:
  Total_order=0
  def __init__(self, Order_ID, weight):
    self.Order_ID=Order_ID
    self.weight=weight
    Fruit.Total_order=Fruit.Total_order+1
  def __str__(self):
    return self.Order_ID+", Weight:"+str(self.weight)

class Mango(Fruit):
  def __init__(self,id,weight,variety,price):
    super().__init__(id,weight)
    self.variety = variety
    self.price = price
  
  def __str__(self):
    self.price = self.price*self.weight
    return "{} Variety: {} Total Price: {}".format(Fruit.__str__(self),self.variety,self.price)

  def __add__(self,other):
    self.total = self.price+other.price
    return "The total Price of the orders are: "+str(self.total)


class JackFruit(Fruit):
  def __init__(self,id,weight,price):
    super().__init__(id,weight)
    self.price = price
  
  def __str__(self):
    self.price = self.price*self.weight
    return "{} Total Price: {}".format(Fruit.__str__(self),self.price)

  def __add__(self,other):
    self.total = self.price+other.price
    return "The total Price of the orders are: "+str(self.total)

m1=Mango("Order Id 1", 5,"GopalVog",250)
print(m1)
m2=Mango("Order Id 2", 5,"HariVanga", 230)
print(m2)
j1=JackFruit("Order Id 3", 5,250)
print(j1)
j2=JackFruit("Order Id 4", 4,210)
print(j2)
print("Total number of Orders:"+str(Fruit.Total_order))
print("==================")
print(m1+m2)
print("==================")
print(j1+j2)
# Out:
# Order Id 1, Weight:5 Variety: GopalVog Total Price: 1250
# Order Id 2, Weight:5 Variety: HariVanga Total Price: 1150
# Order Id 3, Weight:5 Total Price: 1250
# Order Id 4, Weight:4 Total Price: 840
# Total number of Orders:4
# ...
# The total Price of the orders are: 2400
# ...
# The total Price of the orders are: 2090

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
class Student:
  def __init__(self,name,ID):
    self.name = name
    self.ID = ID
  def Details(self):
    return "Name: "+self.name+"\n"+"ID: "+self.ID+"\n"
#Write your code here

class CSEStudent(Student):

  def __init__(self,name,id,sem):
    super().__init__(name,id)
    self.sem = sem

  def Details(self):
    return "{}Current Semester: {}".format(Student.Details(self),self.sem)


  def addCourseWithMarks(self,*items):
    self.l = len(items)
    i = 0
    self.d = {}
    while i < self.l:
      if i%2==0:
        self.d[items[i]] = items[i+1]
      i += 1
    #print(d)
        
  def showGPA(self):
    s = 0
    print("{} has taken {} courses".format(self.name,(self.l/2)))
    for i,j in self.d.items():
      if j >=85:
        g = 4.0
      elif j>= 80:
        g = 3.3 
      elif j>= 70:
        g = 3.0 
      elif j>= 65:
        g = 2.3 
      elif j>= 57:
        g = 2 
      elif j>= 55:
        g = 1.3
      elif j>= 50:
        g = 1.0
      else:
        g = 0.0
      print("{}: {}".format(i,g))
      s = s+(g*3.0)
    gpa = str(s/((self.l/2)*3))
    gpa = gpa[0:4]
    print("GPA of {} is: {}".format(self.name,gpa))


Bob = CSEStudent("Bob","20301018","Fall 2020")
Carol = CSEStudent("Carol","16301814","Fall 2020")
Anny = CSEStudent("Anny","18201234","Fall 2020")
print("#########################")
print(Bob.Details())
print("#########################")
print(Carol.Details())
print("#########################")
print(Anny.Details())
print("#########################")
Bob.addCourseWithMarks("CSE111",83.5,"CSE230",73.0,"CSE260",92.5)
Carol.addCourseWithMarks("CSE470",62.5,"CSE422",69.0,"CSE460",76.5,"CSE461",87.0)
Anny.addCourseWithMarks("CSE340",45.5,"CSE321",95.0,"CSE370",91.0)
print("----------------------------")
Bob.showGPA()
print("----------------------------")
Carol.showGPA()
print("----------------------------")
Anny.showGPA()
# Out:
# #########################
# Name: Bob
# ID: 20301018
# Current Semester: Fall 2020
# #########################
# Name: Carol
# ID: 16301814
# Current Semester: Fall 2020
# #########################
# Name: Anny
# ID: 18201234
# Current Semester: Fall 2020
# #########################
# ----------------------------
# Bob has taken 3.0 courses
# CSE111: 3.3
# CSE230: 3.0
# CSE260: 4.0
# GPA of Bob is: 3.43
# ----------------------------
# Carol has taken 4.0 courses
# CSE470: 2
# CSE422: 2.3
# CSE460: 3.0
# CSE461: 4.0
# GPA of Carol is: 2.82
# ----------------------------
# Anny has taken 3.0 courses
# CSE340: 0.0
# CSE321: 4.0
# CSE370: 4.0
# GPA of Anny is: 2.66

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
class Transport:
  total_traveller = 0
  def __init__(self, name, fare):
    self.name = name
    self.baseFare = fare
  def __str__(self):
    s = "Name: "+self.name+", Base fare: "+str(self.baseFare)
    return s

# Write your codes here.

class Bus(Transport):
  
  def __init__(self,name,fare):
    super(). __init__(name,fare)
    print("Base-fare of Volvo is 950 Taka")

  def addPassengerWithBags(self,*info):
    self.l = len(info)
    Transport.total_traveller += int(self.l/2)
    d = {}
    i = 0
    while i <self.l:
      if i%2==0:
        if info[i+1] <=2:
          ex = 0
        elif info[i+1] <=5:
          ex = 60
        else:
          ex = 105
        d[info[i]] = self.baseFare+ex
      i += 1
      self.d = d

  def __str__(self):
    a = "{} \n".format(Transport.__str__(self))
    b = "Total Passenger(s): {} \n".format(int(self.l/2))
    c= "Passanger details: \n"
    s = ""
    for i, j in self.d.items():
      s = s+"Name: {}, Fare: {} \n".format(i,j)
    return a+b+c+s


class Train(Transport):
  
  def __init__(self,name,fare):
    super(). __init__(name,fare)
    print("Base-fare of Silk City is 850 Taka")

  def addPassengerWithBags(self,*info):
    self.l = len(info)
    Transport.total_traveller += int(self.l/2)
    d = {}
    i = 0
    while i <self.l:
      if i%2==0:
        if info[i+1] <=2:
          ex = 0
        elif info[i+1] <=5:
          ex = 60
        else:
          ex = 105
        d[info[i]] = self.baseFare+ex
      i += 1
      self.d = d

  def __str__(self):
    a = "{} \n".format(Transport.__str__(self))
    b = "Total Passenger(s): {} \n".format(int(self.l/2))
    c= "Passanger details: \n"
    s = ""
    for i, j in self.d.items():
      s = s+"Name: {}, Fare: {} \n".format(i,j)
    return a+b+c+s


# Do not change the following lines of code.
t1 = Bus("Volvo", 950)
print("=================================")
t1.addPassengerWithBags("David", 6, "Mike", 1, "Carol", 3)
print("=================================")
print(t1)
print("=================================")
t2 = Train("Silk City", 850)
print("=================================")
t2.addPassengerWithBags("Bob", 2, "Simon", 4)
print("=================================")
print(t2)
print("=================================")
print("Total Passengers in Transport: ", Transport.total_traveller )
# Out:
# Base-fare of Volvo is 950 Taka
# ...
# Name: Volvo, Base fare: 950
# Total Passenger(s): 3
# Passanger details:
# Name: David, Fare: 1055
# Name: Mike, Fare: 950
# Name: Carol, Fare: 1010
#
# ...
# Base-fare of Silk City is 850 Taka
# ...
# Name: Silk City, Base fare: 850
# Total Passenger(s): 2
# Passanger details:
# Name: Bob, Fare: 850
# Name: Simon, Fare: 910
#
# ...
# Total Passengers in Transport:  5

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
class AppleProduct:
  def __init__(self, name, model,base_price):
    self.name = name
    self.model = model
    self.base_price = base_price
  def companyInfo(self):
    st = ("Company Name: Apple\nFouder: Steve Jobs, Steve Wozniak, Ronald Wayne\nCurrent CEO: Tim Cook\nAddress: Apple Inc, 2511 Laguna Blvd, Elk Grove, CA 95758, United States")
    return st
  def feature(self):
    st = (f"Name: {self.name}\nProduct Model: {self.model}\nHardware Quality: Excellent Hardwares\nGuarantee/ Warranty: Apple Care")
    return st
  def __str__(self):
    print('This is apple product.')
  def calculatePrice(self):
    print('Total Price:', self.base_price)
# Write your codes here.


class MacBookPro2020(AppleProduct):
  basePrice = 1299
  def __init__(self,name,model,ram,chip,tax):
    super().__init__(name,model,MacBookPro2020.basePrice)
    self.ram = ram
    self.chip = chip
    self.tax = tax

  def __str__(self):
    return "Product details: \n{} \nRam: {}\nChip: {}\nCompany Details:\n{}\n ".format(AppleProduct.feature(self),self.ram,self.chip,AppleProduct.companyInfo(self))

  def calculatePrice(self):
    total_tax = (self.base_price*self.tax)/100
    self.total_price = self.base_price + total_tax
    print("Calculating Total Price: \nBase Price: {} \nTax: {}% \nTotal Price: {}".format(self.base_price,self.tax,self.total_price))

  def __add__(self,other):
    return self.total_price+other.total_price



class iphone(AppleProduct):
  basePrice = 799
  def __init__(self,name,model,ram,chip,tax):
    super().__init__(name,model,iphone.basePrice)
    self.ram = ram
    self.chip = chip
    self.tax = tax

  def __str__(self):
    return "Product details: \n{} \nRam: {}\nChip: {}\nCompany Details:\n{}\n ".format(AppleProduct.feature(self),self.ram,self.chip,AppleProduct.companyInfo(self))

  def calculatePrice(self):
    total_tax = (self.base_price*self.tax)/100
    self.total_price = self.base_price + total_tax
    print("Calculating Total Price: \nBase Price: {} \nTax: {}% \nTotal Price: {}".format(self.base_price,self.tax,self.total_price))

  def __add__(self,other):
    return self.total_price+other.total_price





# Do not change the following lines of code.
m1 = MacBookPro2020('MacBook', 'MacBookPro2020', 8, 'M1', 10)
print(m1)
print('====================================')
m1.calculatePrice()
print('###################################')
iphone = iPhone12('iPhone', 'iPhone 12', 8, 'A14', 5)
print(iphone)
print('====================================')
iphone.calculatePrice()
print('###################################')
print('Total Price of these two products: ',end='')
print('%.2f Dollars'%(m1 + iphone))
# Out:
# Product details:
# Name: MacBook
# Product Model: MacBookPro2020
# Hardware Quality: Excellent Hardwares
# Guarantee/ Warranty: Apple Care
# Ram: 8
# Chip: M1
# Company Details:
# Company Name: Apple
# Fouder: Steve Jobs, Steve Wozniak, Ronald Wayne
# Current CEO: Tim Cook
# Address: Apple Inc, 2511 Laguna Blvd, Elk Grove, CA 95758, United States
#
# ...
# Calculating Total Price:
# Base Price: 1299
# Tax: 10%
# Total Price: 1428.9
# ###################################
# Product Details:
# Name: iPhone
# Product Model: iPhone 12
# Hardware Quality: Excellent Hardwares
# Guarantee/ Warranty: Apple Care
# RAM: 8GB
# Chip: A14
# Company Name: Apple
# Fouder: Steve Jobs, Steve Wozniak, Ronald Wayne
# Current CEO: Tim Cook
# Address: Apple Inc, 2511 Laguna Blvd, Elk Grove, CA 95758, United States
# ...
# Calculating Total Price:
# Base Price: 799
# Tax: 5%
# Total Price: 838.95
# ###################################
# Total Price of these two products: 2267.85 Dollars

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
class University:
  name = "ABC University"
  numberOfStudents = 0
  admissionFee = 28000
  Library = 2000
  def __init__(self, n,i):
    self.stName = n
    self.stId = i
  def payment(self):
    return self.admissionFee + self.Library
  def __str__(self):
    return "Student Name: {}, ID: {}\nFee: {}".format(self.stName, self.stId, self.payment())

# Write your codes here

class CSE_dept(University):
  SemesterFee = 7700
  PerCreditFee = 6600
  LabFee = 2750
  def __init__(self,name,id,credits = 6):
    super().__init__(name,id)
    University.numberOfStudents += 1
    self.credits = credits

  def payment(self):
    self.total = University.admissionFee+University.Library+CSE_dept.SemesterFee+(CSE_dept.PerCreditFee*self.credits)+CSE_dept.LabFee
    return self.total

  def payment_details(self):
    print("DETAILS:")
    print("Admission Fee: {} \nLibrary Fee: {} \nSemester Fee: {} \nPer credit fee: {} \nNumber of credits: {} \nLab Fee: {}".format(University.admissionFee,University.Library,CSE_dept.SemesterFee,CSE_dept.PerCreditFee,self.credits,CSE_dept.LabFee))

  def __str__(self):
    return "{}".format(University.__str__(self))

  def __add__(self,other):
    return self.payment() + other.payment()

class PHR_dept(University):
  SemesterFee = 11000
  PerCreditFee = 6600
  def __init__(self,name,id,credits = 9):
    super().__init__(name,id)
    University.numberOfStudents += 1
    self.credits = credits

  def payment(self):
    self.total = University.admissionFee+University.Library+PHR_dept.SemesterFee+(PHR_dept.PerCreditFee*self.credits)
    return self.total

  def payment_details(self):
    print("DETAILS:")
    print("Admission Fee: {} \nLibrary Fee: {} \nSemester Fee: {} \nPer credit fee: {} \nNumber of credits: {}".format(University.admissionFee,University.Library,PHR_dept.SemesterFee,PHR_dept.PerCreditFee,self.credits))

  def __str__(self):
    return "{}".format(University.__str__(self))

  def __add__(self,other):
    return self.payment() + other.payment()



# Do not change the following lines of code.
c1 = CSE_dept("Mary","5678")
print(c1)
c1.payment_details()
print("===========================")
p1 = PHR_dept("Simon","91011")
print(p1)
p1.payment_details()
print("===========================")
c2 = CSE_dept("Adam","1234", 12)
print(c2)
c2.payment_details()
print("===========================")
p2 = PHR_dept("David","121314", 15)
print(p2)
p2.payment_details()
print("===========================")
print("Total Number of Students:",
University.numberOfStudents)
print("Total University Revenue:", (c1 + c2) + (p1 + p2))
print("===========================")
print("Due to the pandemic, admission and library fees have been reduced for all departments. ")
University.admissionFee -= 1000
University.Library -= 100
print("The credit, semester and lab fees have been reduced for the CSE department. ")
CSE_dept.PerCreditFee -= 100
CSE_dept.SemesterFee -= 100
CSE_dept.LabFee -=100
print("The credit and semester fees have been reduced for the PHR department.\n ")
PHR_dept.PerCreditFee -= 100
PHR_dept.SemesterFee -= 1000
print(c1)
print(p1)
print(c2)
print(p2)
print("===========================")
print("Total Number of Students:",
University.numberOfStudents)
print("Total University Revenue:", (c1 + c2) + (p1 + p2))
# Out:
# Student Name: Mary, ID: 5678
# Fee: 80050
# DETAILS:
# Admission Fee: 28000
# Library Fee: 2000
# Semester Fee: 7700
# Per credit fee: 6600
# Number of credits: 6
# Lab Fee: 2750
# ...
# Student Name: Simon, ID: 91011
# Fee: 100400
# DETAILS:
# Admission Fee: 28000
# Library Fee: 2000
# Semester Fee: 11000
# Per credit fee: 6600
# Number of credits: 9
# ...
# Student Name: Adam, ID: 1234
# Fee: 119650
# DETAILS:
# Admission Fee: 28000
# Library Fee: 2000
# Semester Fee: 7700
# Per credit fee: 6600
# Number of credits: 12
# Lab Fee: 2750
# ...
# Student Name: David, ID: 121314
# Fee: 140000
# DETAILS:
# Admission Fee: 28000
# Library Fee: 2000
# Semester Fee: 11000
# Per credit fee: 6600
# Number of credits: 15
# ...
# Total Number of Students: 4
# Total University Revenue: 440100
# ...
# Due to the pandemic, admission and library fees have been reduced for all departments.
# The credit, semester and lab fees have been reduced for the CSE department.
# ...

# %% [markdown]
# ![xxxx.JPG](data:image/jpeg;base64,...)

# %%
class Library:
  Total_book = 1000
  borrow_data = {}
  def __init__(self,n,id):
    self.student_name = n
    self.student_id = id
  def borrowbook(self):
    print("A book is borrowed!")
  def __str__(self):
    return "Library: XYZ"

class Student(Library):
  bCount = 0
  bList = []

  def __init__(self,name,id):
    super().__init__(name,id)

  def borrowbook(self,bName,uId="noOne"):
    self.bName = bName
    self.uId = uId
    if bName not in Student.bList:
      Student.bList.append(bName)
      Student.bCount += 1
      print("A book is borrowed!")
      if uId != "noOne":        
        print("A book is borrowed!")
        print("{} book with the unique id {} is borrowed by {}({})".format(bName,uId,self.student_name,self.student_id))
      else:
        print("{} book is borrowed by {}({})".format(bName,self.student_name,self.student_id))
      xxx = Library.Total_book-Student.bCount
      print("Number of books available for borrowing = {}".format(xxx))
      Library.borrow_data[bName] = [self.student_name]
    else:
      for i,j in Library.borrow_data.items():
        if i == bName:
          print("Sorry {}! {} book is borrowed by {}".format(self.student_name,bName,j[0]))

  def __str__(self):
    b = ""
    for i in Student.bList:
      b = b +i+" ,"
    b = b[0:((len(b))-2)]
    s = "Library: XYZ \nStudent Name: {} ID: {} \nBooks borrowed: {}".format(self.student_name,self.student_id,b)
    return s
  
  def returnAllBooks(self):
    d = {}
    for i,j in Library.borrow_data.items():
      if j[0] != self.student_name:
        d[i] = j
    print("All Books are returned by {}".format(self.student_name))
    Library.borrow_data = d



#Write your code here
s1 = Student("Alice",18101259)
s1.borrowbook("The Alchemist", "Hdw652")
print("===============")
print(s1)
print("===============")
print(Library.borrow_data)
print("===============")
s1.borrowbook("Wuthering Heights")
print("===============")
print(s1)
print("===============")
s2= Student("David",18141777)
s2.borrowbook("The Alchemist", "Hdw652")
print("===============")
s2.borrowbook("The Vampyre")
print("===============")
print(Library.borrow_data)
print("===============")
s1.returnAllBooks()
print("===============")
print(Library.borrow_data)
# Out:
# A book is borrowed!
# A book is borrowed!
# The Alchemist book with the unique id Hdw652 is borrowed by Alice(18101259)
# Number of books available for borrowing = 999
# ...
# Library: XYZ
# Student Name: Alice ID: 18101259
# Books borrowed: The Alchemist
# ...
# {'The Alchemist': ['Alice']}
# ...
# A book is borrowed!
# Wuthering Heights book is borrowed by Alice(18101259)
# Number of books available for borrowing = 998
# ...
# Library: XYZ
# Student Name: Alice ID: 18101259
# Books borrowed: The Alchemist ,Wuthering Heights
# ...
# Sorry David! The Alchemist book is borrowed by Alice
# ...
# A book is borrowed!
# The Vampyre book is borrowed by David(18141777)
# Number of books available for borrowing = 997
# ...
# {'The Alchemist': ['Alice'], 'Wuthering Heights': ['Alice'], 'The Vampyre': ['David']}
# ...
# All Books are returned by Alice
# ...
# {'The Vampyre': ['David']}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Player:
  database={}
  playerNo = 0
  def __init__(self,name,team,jerseyNo):
    self.name = name
    self.team = team
    self.jerseyNo = jerseyNo
  def __str__(self):
    return "Name:{}\nTeam:{}\nJersey No:{}".format(self.name,self.team,self.jerseyNo)

class FootballPlayer(Player):
  def __init__(self,name,team,js,gs,ry ="Not yet retired"):
    super().__init__(name,team,js)
    self.gs = gs
    self.ry = ry
    Player.playerNo += 1

  @classmethod
  def createPlayer(cls,name,team,js,gs,ry):
    return cls(name,team,js,gs,ry)

  def __str__(self):
    x = self.name.split(" ")
    s = ""
    for i in x:
      s = s+i[0]
    id = str(Player.playerNo)+s+str(self.jerseyNo)
    Player.database[id] = [self.name, self.team, self.jerseyNo, self.gs, self.ry]
    return "Player ID: {} \n{} \nGoals Scored: {} \nRetirement date: {}".format(id,Player.__str__(self),self.gs,self.ry)


#Write your code here
print("Number of players:",Player.playerNo)
print("Player Database:",Player.database)
print("#################################")
p1 = FootballPlayer("Lionel Messi","Barcelona",10,231)
print("------Details of the player------")
print(p1)
print("#################################")
p2 = FootballPlayer("Cristiano Ronaldo","Juventus",7,215)
print("------Details of the player------")
print(p2)
print("#################################")
p3 = FootballPlayer.createPlayer("Miroslav Klose","Lazio",11,71,"11 Aug,2014")
print("------Details of the player------")
print(p3)
print("#################################")
print("Number of players:",Player.playerNo)
print("Player Database:",Player.database)
# Out:
# Number of players: 0
# Player Database: {}
# #################################
# ------Details of the player------
# Player ID: 1LM10
# Name:Lionel Messi
# Team:Barcelona
# Jersey No:10
# Goals Scored: 231
# Retirement date: Not yet retired
# #################################
# ------Details of the player------
# Player ID: 2CR7
# Name:Cristiano Ronaldo
# Team:Juventus
# Jersey No:7
# Goals Scored: 215
# Retirement date: Not yet retired
# #################################
# ------Details of the player------
# Player ID: 3MK11
# Name:Miroslav Klose
# Team:Lazio
# Jersey No:11
# Goals Scored: 71
# Retirement date: 11 Aug,2014
# #################################
# Number of players: 3
# Player Database: {'1LM10': ['Lionel Messi', 'Barcelona', 10, 231, 'Not yet retired'], '2CR7': ['Cristiano Ronaldo', 'Juventus', 7, 215, 'Not yet retired'], '3MK11': ['Miroslav Klose', 'Lazio', 11, 71, '11 Aug,2014']}
