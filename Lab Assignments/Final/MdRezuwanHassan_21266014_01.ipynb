# %%
print(0)
# Out:
# 0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
A perfect number is an integer that is the sum of its positive proper divisors (all divisors except itself). 
For example, 6 is a perfect number. The divisors of 6 except itself are 1,2 and 3. The sum of the proper divisors of 6 is 6. 
Thus 6 is a perfect number. You have to take integers as input and continue taking input until the word “STOP” is given as input.
After taking the inputs you have to classify the integers as Perfect and Imperfect and store it in a dictionary(Please see the output for better 
understanding). 

[Note: You CANNOT use any built in functions EXCEPT input(),range(),print()]

# %%
nums = []
while True:
  i =input("Insert number: ")
  if i != "STOP":
    i = int(i)
    nums.append(i)
  else:
    break
per = []
imper = []
for i in nums:
  s = 0
  for j in range(1,i):
    if i%j==0:
      s += j
  if s==i:
    per.append(i)
  else:
    imper.append(i)
d = {}
d["Perfect"] = per
d["Imperfect"] = imper
print(d)
# Out:
# Insert number: 6
# Insert number: 10
# Insert number: 8
# Insert number: 25
# Insert number: 28
# Insert number: 100
# Insert number: 496
# Insert number: 530
# Insert number: STOP
# {'Perfect': [6, 28, 496], 'Imperfect': [10, 8, 25, 100, 530]}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Bus:

  def __init__(self,bName,info):
    self.bName = bName
    self.info = info
    self.ts = 0
    self.tp = 0


  
  def addPassenger(self,pas):
    dh = {}
    s = ""
    pc = 0
    per = pas[0]
    loc = pas[1]
    for i,j in self.info.items():
      if i not in self.info.keys():
        print("Sorry {}, The bus won't go to {}".format(self.,i))
      else:
        self.ts += j
        self.tp += 1
        print(per[0].pName,"Get onto the bus")
        pc += 1
        dh[i] = s+per[0].pName+", "
    k = ""
    for i,j in dh.items():
      k = k+ "{}: {}".format(i,j)+'\n'
    self.pc = pc
    self.k = k

  def showdetails(self):
    print("Total ticket sell: {} Taka".format(self.ts))
    print("Total passenger:",self.pc)
    print(self.k)


  def dropPassesger(self,place):
    del dh[place]
    print("All passengers of are dropped".format(place))


class Passenger 
  
  def __init__(self,pName,dest):
    
    self.pName = pName
    self.dest = dest

  
b=Bus("Volvo",{"Chittagong":1200,"Cumilla":700,"CoxBazar":1500})
p1 = Passenger("Bob", "Chittagong")
print("1=============================")
b.addPassenger(p1)
print("2=============================")
p2 = Passenger("Mike", "CoxBazar")
p3 = Passenger("Carol", "Barisal")
print("3=============================")
b.addPassenger(p2, p3)
print("4=============================")
b.showDetail()
print("5=============================")
p4 = Passenger("Alice", "Chittagong")
p5 = Passenger("David", "CoxBazar")
p6 = Passenger("Simon", "Cumilla")
p7 = Passenger("Tony", "Cumilla")
print("6=============================")
b.addPassenger(p4, p5, p6, p7)
print("7=============================")
b.showDetail()
print("8=============================")
b.dropPassesger("Cumilla")
print("9=============================")
b.showDetail()
print("10=============================")
b.dropPassesger("Chittagong")
print("11============================")
b.showDetail()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Department:
    studentCount = 0
    def __init__(self,name):
        self.name = name
    def __str__(self):
        return "Department Name: " + self.name


class CSEDepartment(Department):

  def __init__(self,dept,val,ch):
    super().__init__(dept)
    self.val = val
    self.ch = ch
    print("{} department’s code value is {}".format(self.name,self.val))

  def addStudentWithSemester(self,*info):
    print("Student ID generated and all students added")
    l = len(info)
    self.ts = int(l/2)
    Department.studentCount += self.ts
    d = {}
    i = 0
    k = self.ts-(self.ts-1)
    while i< l:
      if i%2 != 0:
        x = info[i]
        p = x[-2:]
        #print("pppp",p)
        q = x[0:(len(x)-3)]
        #print("qqqq",q)
        #r = Department.name
        ss = str(self.ts-k)
        #print("ssss",ss)
        if q == "Spring":
          semId = 1
        elif 1 == "Summer":
          semId = 3
        else:
          semId = 2
        #print("semiiiii",semId)
        id = p+str(semId)+self.val+"00"+ss
        #print("idididid",id)
        d[info[i-1]] = id      
      k-=1
      i+=1
    #print(d)
    self.d = d


  def __str__(self):
    s = ""
    a = "{}".format(Department.__str__(self))
    b = "Credit hours: {}".format(self.ch)
    c = "Total Students(s): {}".format(self.ts)
    d = "Student Details:"
    for i,j in self.d.items():
      s = s+"ID: {} Name: {}".format(j,i)+'\n'
    s = s[0:(len(s)-1)]
    return "{} \n{} \n{} \n{} \n{}".format(a,b,c,d,s)

class EEEDepartment(Department):

  def __init__(self,dept,val,ch):
    super().__init__("EEE")
    self.val = val
    self.ch = ch
    print("{} department’s code value is {}".format(self.name,self.val))

  def addStudentWithSemester(self,*info):
    print("Student ID generated and all students added")
    l = len(info)
    self.ts = int(l/2)
    Department.studentCount += self.ts
    d = {}
    i = 0
    k = self.ts-(self.ts-1)
    while i< l:
      if i%2 != 0:
        x = info[i]
        p = x[-2:]
        #print("pppp",p)
        q = x[0:(len(x)-3)]
        #print("qqqq",q)
        #r = Department.name
        ss = str(self.ts-k)
        #print("ssss",ss)
        if q == "Spring":
          semId = 1
        elif 1 == "Summer":
          semId = 3
        else:
          semId = 2
        #print("semiiiii",semId)
        id = p+str(semId)+self.val+"00"+ss
        #print("idididid",id)
        d[info[i-1]] = id      
      k-=1
      i+=1
    #print(d)
    self.d = d


  def __str__(self):
    s = ""
    a = "{}".format(Department.__str__(self))
    b = "Credit hours: {}".format(self.ch)
    c = "Total Students(s): {}".format(self.ts)
    d = "Student Details:"
    for i,j in self.d.items():
      s = s+"ID: {} Name: {}".format(j,i)+'\n'
    s = s[0:(len(s)-1)]
    return "{} \n{} \n{} \n{} \n{}".format(a,b,c,d,s)

#Write your code here
c1 = CSEDepartment("CSE", "01", 136)
print("1=================================")
c1.addStudentWithSemester("Bob", "Spring-20", "Mike", "Fall-20", "Carol", "Summer-21")
print("2=================================")
print(c1)
print("3#################################")
e1 = EEEDepartment("CSE", "21", 136)
print("4=================================")
e1.addStudentWithSemester("David", "Fall-19", "Simon", "Summer-20", "Tony", "Spring-21")
print("5=================================")
print(e1)
print("6=================================")
print("Total Number of Students:", Department.studentCount)
# Out:
# CSE department’s code value is 01
# 1=================================
# Student ID generated and all students added
# 2=================================
# Department Name: CSE
# Credit hours: 136
# Total Students(s): 3
# Student Details:
# ID: 20101003 Name: Bob
# ID: 20201005 Name: Mike
# ID: 21201007 Name: Carol
# 3#################################
# EEE department’s code value is 21
# 4=================================
# Student ID generated and all students added
# 5=================================
# Department Name: EEE
# Credit hours: 136
# Total Students(s): 3
# Student Details:
# ID: 19221003 Name: David
# ID: 20221005 Name: Simon
# ID: 21121007 Name: Tony
# 6=================================
# Total Number of Students: 6

# %%
ID: 20101001 Name: Bob
ID: 20201002 Name: Mike
ID: 21301003 Name: Carol

ID: 19221001 Name: David
ID: 20321002 Name: Simon
ID: 21121003 Name: Tony
# Out:
#   File "<ipython-input-46-e5e18578a042>", line 1
#     ID: 20101001 Name: Bob
#                     ^
# SyntaxError: invalid syntax
