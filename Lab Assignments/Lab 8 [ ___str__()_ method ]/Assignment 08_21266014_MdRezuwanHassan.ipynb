# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class RealNumber:
  def __init__(self, r=0):
    self.__realValue = r
  
  def getRealValue(self):
    return self.__realValue
  
  def setRealValue(self, r):
    self.__realValue = r
  
  def __str__(self):
    return 'RealPart: '+str(self.getRealValue())


class ComplexNumber(RealNumber):
  
  def __init__(self,real = 1,imaginary = 1):
    super().__init__(real)
    self.imaginary = imaginary
    
  
  def __str__(self):
    return "{}.0 \nImaginaryPart: {}.0".format(RealNumber.__str__(self),self.imaginary)

cn1 = ComplexNumber()
print(cn1)
print('---------')
cn2 = ComplexNumber(5,7)
print(cn2)
# Out:
# RealPart: 1.0
# ImaginaryPart: 1.0
# ---------
# RealPart: 5.0
# ImaginaryPart: 7.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class RealNumber:
  def __init__(self, number=0):
    self.number = number
  def __add__(self, anotherRealNumber):
    return self.number + anotherRealNumber.number
  def __sub__(self, anotherRealNumber):
    return self.number - anotherRealNumber.number
  def __str__(self):
    return str(self.number)

class ComplexNumber(RealNumber):

  def __init__(self,r,i):
    if isinstance(r,RealNumber):
      self.r = int(r.number)
    else:
      self.r = int(r)
    self.i = int(i)

  def __add__(self, other):
    x =  self.r + other.r
    y = self.i + other.i
    return ComplexNumber(x,y)
  
  def __sub__(self, other):
    x =  self.r - other.r
    y = self.i - other.i
    return ComplexNumber(x,y)
  
  
  def __str__(self):
    if self.r > 0 and self.i > 0:
      s = "{} + {}i".format(abs(self.r),abs(self.i))
    elif self.r > 0 and self.i < 0:
      s = "{} - {}i".format(abs(self.r),abs(self.i))
    elif self.r < 0 and self.i > 0:
      s = "-{} + {}i".format(abs(self.r),abs(self.i))
    else:
      s = "-{} - {}i".format(abs(self.r),abs(self.i))
    return s


r1 = RealNumber(3)
r2 = RealNumber(5)
print(r1+r2)
cn1 = ComplexNumber(2, 1)
print(cn1)
cn2 = ComplexNumber(r1, 5)
print(cn2)
cn3 = cn1 + cn2
print(cn3)
cn4 = cn1 - cn2
print(cn4)
# Out:
# 8
# 2 + 1i
# 3 + 5i
# 5 + 6i
# -1 - 4i

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Account:
  def __init__(self, balance):
    self._balance = balance
  def getBalance(self):
    return self._balance

class CheckingAccount(Account):
  numberOfAccount = 0
  def __init__ (self,balance = 0):
    super().__init__(balance)
    CheckingAccount.numberOfAccount += 1
  

  def __str__(self):
    return "Account Balance: {}".format(float(self._balance))

print('Number of Checking Accounts: ', CheckingAccount.numberOfAccount)
print(CheckingAccount())
print(CheckingAccount(100.00))
print(CheckingAccount(200.00))
print('Number of Checking Accounts: ', CheckingAccount.numberOfAccount)
# Out:
# Number of Checking Accounts:  0
# Account Balance: 0.0
# Account Balance: 100.0
# Account Balance: 200.0
# Number of Checking Accounts:  3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Fruit:
  def __init__(self, formalin=False, name=''):
    self.__formalin = formalin
    self.name = name
  def getName(self):
    return self.name
  def hasFormalin(self):
    return self.__formalin

class testFruit:
  def test(self, f):
    print('----Printing Detail----')
    if f.hasFormalin():
      print('Do not eat the',f.getName(),'.')
      print(f)
    else:
      print('Eat the',f.getName(),'.')
      print(f)


class Mango(Fruit,testFruit):

  def __init__(self,formalin = True,name = "Mango"):
    super().__init__(formalin,name)

  def __str__(self):
    return "Mangos are bad for you."

class Jackfruit(Fruit,testFruit):

  def __init__(self,formalin = False,name = "Jackfruit"):
    super().__init__(formalin,name)

  def __str__(self):
    return "Jack fruits are good for you."

m = Mango()
j = Jackfruit()
t1 = testFruit()
t1.test(m)
t1.test(j)
# Out:
# ----Printing Detail----
# Do not eat the Mango .
# Mangos are bad for you.
# ----Printing Detail----
# Eat the Jackfruit .
# Jack fruits are good for you.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Exam:
  def __init__(self,marks):
    self.marks = marks
    self.time = 60
  def examSyllabus(self):
    return "Maths , English"
  def examParts(self):
    return "Part 1 - Maths\nPart 2 - English\n"


class ScienceExam(Exam):

  def __init__(self,marks,time,*parts):
    super().__init__(marks)
    self.time = time
    self.parts = parts
    self.lenParts = len(parts)

  def __str__(self):
    return ("Marks: {} Time: {} minutes Number of Parts: {}".format(self.marks,self.time,(self.lenParts+2)))

  def examSyllabus(self):
    p = " "
    for i in self.parts:
      p =p+i+", "
    x = "Maths , English,"+p
    return "{}".format(x)


  def examParts(self):
    x = 3
    i = 0
    p = ""

    while (i <self.lenParts):
      p = p+"part {} - {}\n".format(x,self.parts[i])
      x += 1
      i += 1
    
    self.p = p

    y = "\nPart 1 - Maths\nPart 2 - English\n"+self.p
    return "{}".format(y)


engineering = ScienceExam(100,90,"Physics","HigherMaths")
print(engineering)
print('----------------------------------')
print(engineering.examSyllabus())
print(engineering.examParts())
print('==================================')
architecture = ScienceExam(100,120,"Physics","HigherMaths","Drawing")
print(architecture)
print('----------------------------------')
print(architecture.examSyllabus())
print(architecture.examParts())
# Out:
# Marks: 100 Time: 90 minutes Number of Parts: 4
# ----------------------------------
# Maths , English, Physics, HigherMaths,
#
# Part 1 - Maths
# Part 2 - English
# part 3 - Physics
# part 4 - HigherMaths
#
# ==================================
# Marks: 100 Time: 120 minutes Number of Parts: 5
# ----------------------------------
# Maths , English, Physics, HigherMaths, Drawing,
#
# Part 1 - Maths
# Part 2 - English
# part 3 - Physics
# part 4 - HigherMaths
# part 5 - Drawing

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Shape3D:
  pi = 3.14159

  def __init__(self, name = 'Default', radius = 0):
    self._area = 0
    self._name = name
    self._height = 'No need'
    self._radius = radius
  def calc_surface_area(self):
    return 2 * Shape3D.pi * self._radius
  def __str__(self):
    return "Radius: "+str(self._radius)

class Sphere(Shape3D):
  def __init__(self,name,radius):
    super().__init__(name,radius)
    self.height = "No need"
    print("Shape name: {}, Area Formula: 4*pi*r^2".format(self._name))

  def calc_surface_area(self):
    self.arr = Shape3D.calc_surface_area(self)*2*self._radius
    return self.arr
  
  def __str__(self):
    return "{}, Height: {} \nArea: {}".format(Shape3D.__str__(self),self.height,self.arr)


class Cylinder(Shape3D):
  def __init__(self,name,radius,height):
    super().__init__(name,radius)
    self.height = height
    print("Shape name: {}, Area Formula: 2*pi*r(r+h)".format(self._name))

  def calc_surface_area(self):
    self.arr = Shape3D.calc_surface_area(self)*(self._radius+self.height)
    return self.arr

  def __str__(self):
    return "{}, Height: {} \nArea: {}".format(Shape3D.__str__(self),self.height,self.arr)

    


sph = Sphere('Sphere', 5)
print('----------------------------------')
sph.calc_surface_area()
print(sph)
print('==================================')
cyl = Cylinder('Cylinder', 5, 10)
print('----------------------------------')
cyl.calc_surface_area()
print(cyl)
# Out:
# Shape name: Sphere, Area Formula: 4*pi*r^2
# ----------------------------------
# Radius: 5, Height: No need
# Area: 314.159
# ==================================
# Shape name: Cylinder, Area Formula: 2*pi*r(r+h)
# ----------------------------------
# Radius: 5, Height: 10
# Area: 471.2385

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
class PokemonBasic:
  def __init__(self, name = 'Default', hp = 0,weakness = 'None', type = 'Unknown'):
    self.name = name
    self.hit_point = hp
    self.weakness = weakness
    self.type = type
  def get_type(self):
    return 'Main type: ' + self.type
  def get_move(self):
    return 'Basic move: ' + 'Quick Attack'
  def __str__(self):
    return "Name: " + self.name + ", HP: " + str(self.hit_point) + ", Weakness: " + self.weakness

class PokemonExtra(PokemonBasic):
  def __init__(self,name,hp,weakness,mType,sType = None,oMove = None):
    super().__init__(name,hp,weakness,mType)
    self.sType = sType
    self.oMove = oMove

  def __str__(self):
    return "{}".format(PokemonBasic.__str__(self))

  def get_type(self):
    if self.sType != None:
      return 'Main type: {}, Secondary type: {}'.format(self.type,self.sType)
    else:
      return 'Main type: {}'.format(self.type)


  
  def get_move(self):
    if self.oMove != None:
      s = ""
      for i in self.oMove:
        s = s+i+", "
      s = s[0:(len(s)-2)]
      return "Basic move: Quick Attack \nOther move: {}".format(s)
    
    else:
      return PokemonBasic.get_move(self)

print('\n------------Basic Info:--------------')
pk = PokemonBasic()
print(pk)
print(pk.get_type())
print(pk.get_move())
print('\n------------Pokemon 1 Info:-------------')
charmander = PokemonExtra('Charmander', 39, 'Water', 'Fire')
print(charmander)
print(charmander.get_type())
print(charmander.get_move())
print('\n------------Pokemon 2 Info:-------------')
charizard = PokemonExtra('Charizard', 78, 'Water', 'Fire', 'Flying', ('Fire Spin', 'Fire Blaze'))
print(charizard)
print(charizard.get_type())
print(charizard.get_move())
# Out:
# ------------Basic Info:--------------
# Name: Default, HP: 0, Weakness: None
# Main type: Unknown
# Basic move: Quick Attack
#
# ------------Pokemon 1 Info:-------------
# Name: Charmander, HP: 39, Weakness: Water
# Main type: Fire
# Basic move: Quick Attack
#
# ------------Pokemon 2 Info:-------------
# Name: Charizard, HP: 78, Weakness: Water
# Main type: Fire, Secondary type: Flying
# Basic move: Quick Attack
# Other move: Fire Spin, Fire Blaze

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Team:
  def __init__(self, name):
    self.name = "default"
    self.total_player = 5
  def info(self):
    print("“We love sports")


class FootBallTeam(Team):
  total_player = 11

  def __init__(self,name):
    self.name = name
  
  def info(self):
    print("Our name is",self.name)
    print("We play Football")
    print("We love sports")

class CricketTeam(Team):
  total_player = 11

  def __init__(self,name):
    self.name = name
  
  def info(self):
    print("Our name is",self.name)
    print("We play Cricket")
    print("We love sports")


class Team_test:

  def check(self, tm):
    print("=========================")
    print("Total Player:", tm.total_player)
    tm.info()

f = FootBallTeam("Brazil")
c = CricketTeam("Bangladesh")
test = Team_test()
test.check(f)
test.check(c)
# Out:
# =========================
# Total Player: 11
# Our name is Brazil
# We play Football
# We love sports
# =========================
# Total Player: 11
# Our name is Bangladesh
# We play Cricket
# We love sports

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Pokemon:
  def __init__(self, p):
    self.pokemon = p
    self.pokemon_type = "Needs to be set"
    self.pokemon_weakness = "Needs to be set"
  def kind(self):
    return self.pokemon_type
  def weakness(self):
    return self.pokemon_weakness
  def what_am_i(self):
    print("I am a Pokemon.")

class Pikachu(Pokemon):
  def __init__(self):
    self.pokemon = "Pikachu"
  def kind(self):
    return "Electric"
  def weakness(self):
    return "Ground"
  def what_am_i(self):
    self.x = Pokemon.what_am_i(self)
    self.y = "I am a "+self.pokemon
    print(self.y)


class Charmander(Pokemon):
  def __init__(self):
    self.pokemon = "Charmander"
  def kind(self):
    return "Fire"
  def weakness(self):
    return "Water, Ground, Rock"
  def what_am_i(self):
    self.x = Pokemon.what_am_i(self)
    self.y = "I am a "+self.pokemon
    print(self.y)


pk1 = Pikachu()
print("Pokemon:", pk1.pokemon)
print("Type:", pk1.kind())
print("Weakness:", pk1.weakness())
pk1.what_am_i()
print("========================")
c1 = Charmander()
print("Pokemon:", c1.pokemon)
print("Type:", c1.kind())
print("Weakness:", c1.weakness())
c1.what_am_i()
# Out:
# Pokemon: Pikachu
# Type: Electric
# Weakness: Ground
# I am a Pokemon.
# I am a Pikachu
# ========================
# Pokemon: Charmander
# Type: Fire
# Weakness: Water, Ground, Rock
# I am a Pokemon.
# I am a Charmander

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Department:
  def __init__(self, s):
    self.semester = s
    self.name = "Default"
    self.id = -1
  def student_info(self):
    print("Name:", self.name)
    print("ID:", self.id)
  def courses(self, c1, c2, c3):
    print("No courses Approved yet!")


class CSE(Department):

  def __init__(self,name,id,semester):
    super().__init__(semester)
    self.name = name
    self.id = id
  
  def student_info(self):
    return Department.student_info(self)
  
  def courses(self,c1,c2,c3):
    s = c1+'\n'+c2+'\n'+c3
    print("Courses Approved to this CSE student in {} semester :".format(self.semester))
    print(s)


class EEE(Department):

  def __init__(self,name,id,semester):
    super().__init__(semester)
    self.name = name
    self.id = id
  
  def student_info(self):
    return Department.student_info(self)
  
  def courses(self,c1,c2,c3):
    s = c1+'\n'+c2+'\n'+c3
    print("Courses Approved to this EEE student in {} semester :".format(self.semester))
    print(s)


s1 = CSE("Rahim", 16101328,"Spring2016")
s1.student_info()
s1.courses("CSE110", "MAT110", "ENG101")
print("==================")
s2 = EEE("Tanzim", 18101326, "Spring2018")
s2.student_info()
s2.courses("Mat110", "PHY111", "ENG101")
print("==================")
s3 = CSE("Rudana", 18101326, "Fall2017")
s3.student_info()
s3.courses("CSE111", "PHY101", "MAT120")
print("==================")
s4 = EEE("Zainab", 19201623, "Summer2019")
s4.student_info()
s4.courses("EEE201", "PHY112", "MAT120")
# Out:
# Name: Rahim
# ID: 16101328
# Courses Approved to this CSE student in Spring2016 semester :
# CSE110
# MAT110
# ENG101
# ==================
# Name: Tanzim
# ID: 18101326
# Courses Approved to this EEE student in Spring2018 semester :
# Mat110
# PHY111
# ENG101
# ==================
# Name: Rudana
# ID: 18101326
# Courses Approved to this CSE student in Fall2017 semester :
# CSE111
# PHY101
# MAT120
# ==================
# Name: Zainab
# ID: 19201623
# Courses Approved to this EEE student in Summer2019 semester :
# EEE201
# PHY112
# MAT120
